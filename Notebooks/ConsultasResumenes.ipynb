# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:3030/InvestigacionesUdenar/sparql")
sparql.setQuery("""

PREFIX po: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
select ?id_pi?Titulo?proyecto_investigacion (count(?id_pi)as ?c)
where{
        # ?proyecto_investigacion po:pi_tiene_palabra ?palabra.
        # ?proyecto_investigacion po:titulo_proyecto_investigacion ?Titulo.
        # ?proyecto_investigacion po:id_proyecto_investigacion ?id_pi.
        # ?palabra po:descripcion_palabra ?descripcion.
        FILTER (
            REGEX(str(?descripcion), 'descubrimiento','i')||
            REGEX(str(?descripcion), 'conocimiento','i')
        )
    }
group by ?id_pi?Titulo?proyecto_investigacion
order by DESC(?c)
""")

#order by DESC(?c)

sparql.setReturnFormat(JSON)

results = sparql.query().convert()
results = results['results']['bindings']
results
# Out:
# [{'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '320'},
#   'Titulo': {'type': 'literal',
#    'value': 'APROXIMACIÓN AL PENSAMIENTO JURÍDICO NARIÑENSE DESDE LAS FIGURAS DE JOSÉ RAFAEL SAÑUDO Y ERNESTO VELA ANGULO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi320'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '6'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '204'},
#   'Titulo': {'type': 'literal',
#    'value': 'HONGOS FITOPATÓGENOS ASOCIADOS AL LAUREL DE CERA Morella pubescens'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi204'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '5'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '312'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANÁLISIS DE LA CONTRIBUCIÓN SOCIOECONÓMICA DE LAS MUJERES TRABAJADORAS EN LAS ZONAS RURALES DEL MUNICIPIO DE GUACHUCAL-DEPARTAMENTO DE NARIÑO. 2018'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi312'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '352'},
#   'Titulo': {'type': 'literal',
#    'value': 'DISEÑO COLABORATIVO DE ESTRATEGIAS INTEGRALES PARA LUGARES DE ESPARCIMIENTO JUVENIL EN LA CIUDAD DE PASTO QUE FORTALEZCAN SU RECONOCIMIENTO E IMPULSEN EL TURISMO URBANO CON PROPIOS Y TURISTAS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi352'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '375'},
#   'Titulo': {'type': 'literal',
#    'value': 'Estudio de la Personalidad de los Gerentes de 12 Empresas Medianas con "Goodwill" en la Ciudad de San Juan de Pasto, Año 2017'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi375'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '193'},
#   'Titulo': {'type': 'literal',
#    'value': 'Fortalecimiento de las actitudes tendientes a prevenir las manifestaciones de violencia basada en género en administrativos, docentes y estudiantes en la Universidad de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi193'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '230'},
#   'Titulo': {'type': 'literal',
#    'value': 'La historia crítica del arte en Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi230'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '231'},
#   'Titulo': {'type': 'literal',
#    'value': 'La lucha territorial de los indígenas en La Guerra de los Conventillos y otras revueltas locales.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi231'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '433'},
#   'Titulo': {'type': 'literal',
#    'value': 'RECONOCIMIENTO INTERESPECIFICO DEL CANTO ENTRE Epipedobates boulengeri y E. narinensis (Anura: Dendrobatidae) DEL PACIFICO DE NARIÑO, COLOMBIA.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi433'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '310'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANÁLISIS DE ALGORITMOS PARALELOS PARA LA TAREA DE MINERÍA DE DATOS ASOCIACIÓN'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi310'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '311'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANÁLISIS DE FUNCIONALIDAD DE LA HERRAMIENTA DE INTELIGENCIA DE NEGOCIOS DE SOFTWARE LIBRE SPAGO BI ORIENTADA AL USO EN LAS PYMES DE LA REGIÓN'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi311'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '24'},
#   'Titulo': {'type': 'literal',
#    'value': 'APLICACIÓN DE TÉCNICAS DE MINERÍA DE DATOS PARA EL DESCUBRIMIENTO DE FACTORES ASOCIADOS AL DESEMPEÑO ACADÉMICO EN LAS PRUEBAS SABER 5° DE LOS ESTUDIANTES DE LAS INSTITUCIONES EDUCATIVAS DEL DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi24'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '337'},
#   'Titulo': {'type': 'literal',
#    'value': 'CONSTRUCCIÓN DE UN REPOSITORIO LIMPIO DE DATOS PARA LA DETECCIÓN DE PATRONES DE EVENTOS ERUPTIVOS DEL VOLCÁN GALERAS CON TÉCNICAS DE MINERÍA DE DATOS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi337'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '65'},
#   'Titulo': {'type': 'literal',
#    'value': 'DESCUBRIMIENTO DE FACTORES ASOCIADOS AL DESEMPEÑO ACADÉMICO EN LAS PRUEBAS SABER 11° DE LOS ESTUDIANTES DE LAS INSTITUCIONES EDUCATIVAS DEL DEPARTAMENTO DE NARIÑO CON TÉCNICAS DESCRIPTIVAS DE MINERÍA DE DATOS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi65'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '119'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO DE LA CINÉTICA DE PÉRDIDA DE HUMEDAD Y ABSORCIÓN DE ACEITE DURANTE LA FRITURA DE ARVEJA (PISUM SATIVUM L), DE DOS VARIEDADES CULTIVADAS EN EL DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi119'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '154'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DE LAS CARACTERÍSTICAS FISICOQUIMICAS, FISIOLOGICAS Y BROMATOLOGICAS DEL FRUTO DEL OBO (Spondias sp) PARA SU PROCESAMIENTO AGROINDUSTRIAL'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi154'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '417'},
#   'Titulo': {'type': 'literal',
#    'value': 'MAKIPURAY: UNA HERRAMIENTA WEB DE INTELIGENCIA DE NEGOCIOS PARA EL DESCUBRIMIENTO DE CONOCIMIENTO ORIENTADA A LAS PYME DEL DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi417'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '445'},
#   'Titulo': {'type': 'literal',
#    'value': 'UN MERCADO DE DATOS PARA EL ANÁLISIS MULTIDIMENSIONAL DE LAS PRUEBAS SABER 5 DE LAS INSTITUCIONES EDUCATIVAS DE LOS MUNICIPIOS DE LA SUBREGIÓN DE OBANDO DEL DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi445'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'},
#   'Titulo': {'type': 'literal',
#    'value': '"Diagnóstico del impacto de las iniciativas emprendedoras de los egresados del programa de diseño industrial de la Universidad de Nariño"'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi1'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '3'},
#   'Titulo': {'type': 'literal',
#    'value': 'ACTIVIDAD ANTIBACTERIAL DE POLIFENOLES DEL AGUACATE (Persea americana var. Hass) SOBRE Helicobacter pylori AISLADO DE PACIENTES DE UNA ZONA DE ALTO RIESGO DE CANCER GASTRICO DEL DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi3'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '6'},
#   'Titulo': {'type': 'literal',
#    'value': 'ALMACENAMIENTO DE CARBONO EN EL SUELO Y LA BIOMASA ARBOREA EN DIFERENTES SISTEMAS DE USO DEL SUELO DE LA ZONA ALTO ANDINA, DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi6'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '14'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANALISIS DEL VALOR AGREGADO GENERADO POR LA UNIVERSIDAD DE NARIÑO EN RELACION A LAS PRUEBAS SABER 11 - SABER PRO 2014-2016.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi14'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '10'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANÁLISIS DE LA DIVERSIDAD BACTERIANA DEL CÁTODO DE UNA CELDA DE COMBUSTIBLE MICROBIANA REDUCTORA DE CROMO HEXAVALENTE - Cr(VI).'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi10'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '18'},
#   'Titulo': {'type': 'literal',
#    'value': 'ANÁLISIS TEÓRICO JURÍDICO DESDE CONTEXTOS REGIONALES: PENSAMIENTO JURÍDICO EN NARIÑO EN EL PERÍODO 1904 -1970'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi18'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '21'},
#   'Titulo': {'type': 'literal',
#    'value': 'APLICACIÓN DE LA MINERÍA DE DATOS EN LA DETECCIÓN DE PATRONES DE DESEMPEÑO EN LAS COMPETENCIAS GENÉRICAS DE LAS PRUEBAS SABER PRO 2012, 2013 y 2014 DE LOS ESTUDIANTES DE LOS PROGRAMAS PROFESIONALES DE LA UNIVERSIDAD DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi21'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '25'},
#   'Titulo': {'type': 'literal',
#    'value': 'APLICACIÓN DE UNA METODOLOGÍA de TRABAJO INTERDISCIPLINARIA, CON ENFOQUE DE ACCIÓN SIN DAÑO EN EL RELACIONAMIENTO ACADEMIA - COMUNIDAD PARA EL DESARROLLO LOCAL, EN LAS MICROCUENCAS DE MIRAFLORES MUNICIPIO DE TANGUA Y MIJITAYO MUNICIPIO DE PASTO, DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi25'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '321'},
#   'Titulo': {'type': 'literal',
#    'value': 'APROXIMACION AL RIESGO DE INUNDACION Y ENTERRAMIENTO POR LAHARES PROVENIENTES DE LA QUEBRADA MIJITAYO EN EL SECTOR DE TAMASAGRA Y ZONAS ALEDAÑAS.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi321'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '4'},
#   'Titulo': {'type': 'literal',
#    'value': 'Actividad antibacterial y citotóxica in vitro de aceites vegetales de semillas de frutas tropicales y andinas.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi4'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '7'},
#   'Titulo': {'type': 'literal',
#    'value': 'Análisis curricular de programas de grado de la Facultad de Artes de la Universidad de Nariño con fines de reforma y acreditación. Caso: Diseño Gráfico.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi7'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '8'},
#   'Titulo': {'type': 'literal',
#    'value': 'Análisis curricular de programas de pregrado de la Facultad de Artes de la Universidad de Nariño con fines de reforma y acreditación. Caso: Diseño Industrial'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi8'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '9'},
#   'Titulo': {'type': 'literal',
#    'value': 'Análisis de factores de aprendizaje en seguridad alimentaria con comunidades rurales en el municipio de Pasto, departamento de Nariño.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi9'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '12'},
#   'Titulo': {'type': 'literal',
#    'value': 'Análisis de la percepción de jóvenes rurales frente al ecoturismo en el Centro Ambiental Chimayoy, municipio de Pasto, Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi12'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '13'},
#   'Titulo': {'type': 'literal',
#    'value': 'Análisis de los procesos creativos de los artesanos del Carnaval de Negros y Blancos de San Juan de Pasto en el desarrollo de las carrozas ganadoras periodo 2010-2019, para la preservación y transmisión de los saberes ancestrales hacia una memoria cultural a partir del uso del diseño, la innovación y las nuevas tecnologías.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi13'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '28'},
#   'Titulo': {'type': 'literal',
#    'value': 'Aproximación al intercambio de conocimiento en diseño, mediante los procesos de co-creación, logrados al interior del Proyecto Mtic-design Knowledge Exchange Program - Universidad de Nariño 2016'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi28'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '34'},
#   'Titulo': {'type': 'literal',
#    'value': 'CARACTERIZACIÓN AEROBIA Y ANAEROBIA DEL ÁREA DE INFLUENCIA DE LA PRODUCCIÓN DE TRUCHA ARCOÍRIS (Oncorhynchus mykiss) DE LA ESTACIÓN PISCÍCOLA INTIYACO EN EL LAGO GUAMUEZ DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi34'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '38'},
#   'Titulo': {'type': 'literal',
#    'value': 'CARACTERIZACIÓN DEL ESPACIO ECONÓMICO Y SOCIAL DE FRONTERA ENTRE COLOMBIA Y ECUADOR (EFSCE).'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi38'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '47'},
#   'Titulo': {'type': 'literal',
#    'value': 'COMPARACIÓN DE DOS SISTEMAS DE PRODUCCIÓN DE CUYES (Cavia porcellus): TRADICIONAL Y TECNIFICADO, MEDIANTE LA EVALUACIÓN MICROSCÓPICA, HISTOQUÍMICA E INMUNOHISTOQUIMICA DEL TRACTO GASTROINTESTINAL.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi47'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '331'},
#   'Titulo': {'type': 'literal',
#    'value': 'COMPARACIÓN DEL RENDIMIENTO Y CALIDAD DEL ACEITE VEGETAL EXTRAÍDO DE PULPA DE AGUACATE (Persea americana Mill) MEDIANTE EXTRACCIÓN SOXHLET CON ETANOL, HEXANO Y EXTRACCIÓN CON CO2 SUPERCRÍTICO, COMO ALTERNATIVA PARA DISMINUIR LAS PERDIDAS POSTCOSECHA EN LA PRODUCCIÓN DE AGUACATE EN EL DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi331'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '332'},
#   'Titulo': {'type': 'literal',
#    'value': 'COMPARACIÓN DEL TAMAÑO MÍNIMO DE LA MADUREZ SEXUAL Y DE LA POSTURA DE Pristimantis myersi y Pristimantis unistrigatus (ANURA, CRAUGASTORIDAE) DISTRIBUIDAS EN LOS DEPARTAMENTOS DE NARIÑO Y CAUCA.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi332'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '334'},
#   'Titulo': {'type': 'literal',
#    'value': 'COMUNICACIÓN EN LA MOVILIDAD URBANA: nuevas perspectivas desde el diseño industrial (modalidad, creacion artistica y cultural)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi334'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '338'},
#   'Titulo': {'type': 'literal',
#    'value': 'CONTENIDO DE BETALAÍNAS Y ACTIVIDAD ANTIOXIDANTE IN-VITRO DEL ULLUCO (Ullucus tuberosus)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi338'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '55'},
#   'Titulo': {'type': 'literal',
#    'value': 'CRITERIOS DE EVALUACIÓN EMPLEADOS POR LOS DOCENTES EN LA EVALUACIÓN DE LA PRODUCCIÓN ESCRITA DE LOS ESTUDIANTES DE LA LICENCIATURA EN LENGUA CASTELLANA Y LITERATURA'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi55'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '343'},
#   'Titulo': {'type': 'literal',
#    'value': 'CUANTIFICACION DEL ALMACENAMIENTO DE CARBONO DE LEÑOSAS PERENNES EN EL MUNICIPIO DE PASTO DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi343'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '56'},
#   'Titulo': {'type': 'literal',
#    'value': 'CULTIVO DEL HONGO MEDICINAL Pleurotus ostreatus Y DETERMINACIÓN DE SU ACTIVIDAD ENZIMÁTICA Y ANTIOXIDANTE'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi56'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '30'},
#   'Titulo': {'type': 'literal',
#    'value': 'Calidad de Vida Laboral (CVL) en relación a los roles de género en docentes de la Universidad de Nariño.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi30'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '39'},
#   'Titulo': {'type': 'literal',
#    'value': 'Caracterización del juego autóctono de la chaza de la región suroccidental del departamento de Nariño, para su implementación lúdica y educativa en entornos digitales a través de aplicaciones en realidad aumentada o virtual.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi39'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '329'},
#   'Titulo': {'type': 'literal',
#    'value': 'Ciudarnos: Proyecto de Investigación - creación sobre la estética cotidiana en los sujetos y los espacios de San Juan de Pasto.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi329'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '48'},
#   'Titulo': {'type': 'literal',
#    'value': 'Comportamiento proecológico y austero en el personal administrativo, en el marco del Sistema de Gestión Ambiental de la Universidad de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi48'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '49'},
#   'Titulo': {'type': 'literal',
#    'value': 'Comprensión de la experiencia moral y el significado de cultura de paz en un grupo de agentes sociales, no gubernamentales y gubernamentales del departamento de Nariño -Colombia.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi49'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '336'},
#   'Titulo': {'type': 'literal',
#    'value': 'Conocimiento local sobre especias arbóreas con potencial agroforestal en el corregimiento de Morasurco Pasto Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi336'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '53'},
#   'Titulo': {'type': 'literal',
#    'value': 'Convivencia escolar entre estudiantes de la Institución Educativa Municipal Luis Delfín Insuasty Rodríguez INEM de Pasto: Encuentros y tensiones generacionales.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi53'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '345'},
#   'Titulo': {'type': 'literal',
#    'value': 'DEFINICIÓN DE UNA PRACTICA DE DESARROLLO DE SOFTWARE PARA EQUIPOS DE TRABAJO SIN RESTRICCIONES DE TIEMPO Y ESPACIO UTILIZANDO LOS PRINCIPIOS DE SEMAT'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi345'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '68'},
#   'Titulo': {'type': 'literal',
#    'value': 'DETECCIÓN SEROLÓGICA Y MOLECULAR DE VIRUS ASOCIADOS A ACHIRA (Canna edulis Ker.) EN NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi68'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '346'},
#   'Titulo': {'type': 'literal',
#    'value': 'DETERMINACIÓN DE ACETOGENINAS PRESENTES EN SEMILLAS DE Annona muricata (GUANÁBANA) MEDIANTE CROMATOGRAFÍA LIQUIDA DE ALTA EFICIENCIA'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi346'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '71'},
#   'Titulo': {'type': 'literal',
#    'value': 'DETERMINACIÓN DE PRINCIPIOS ACTIVOS MEDICINALES DEL HONGO Ganoderma lucidum CULTIVADO SOBRE RESIDUOS SÓLIDOS Y SU USO EN LA PRODUCCIÓN DE UN ALIMENTO FUNCIONAL'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi71'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '349'},
#   'Titulo': {'type': 'literal',
#    'value': 'DIAGNÓSTICO DEL SISTEMA ACTUAL DE MANEJO DE RESIDUOS EN SAN ANDRÉS DE TUMACO DE ACUERDO CON LA METODOLOGÍA DE LA GUÍA DE PLANEACIÓN ESTRATÉGICA PROPUESTA POR EL MINISTERIO DE VIVIENDA, AGUA Y SANEAMIENTO BÁSICO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi349'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '80'},
#   'Titulo': {'type': 'literal',
#    'value': 'DISEÑO Y ESTABLECIMIENTO DE UNA BIBLIOTECA BIOACÚSTICA DE REFERENCIA DE LAS AVES DEL SUROCCIDENTE COLOMBIANO COMO HERRAMIENTA DE APOYO A PROCESOS INVESTIGATIVOS DE LA UNIVERSIDAD DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi80'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '58'},
#   'Titulo': {'type': 'literal',
#    'value': 'Desarrollo de microencapsulados a partir del aprovechamiento integral de limón Tahití (Citrus latifolia) en el departamento de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi58'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '62'},
#   'Titulo': {'type': 'literal',
#    'value': 'Desarrollo de una estrategia pedagógica que facilite la articulación de las prácticas del dibujo analógico y digital en diseño industrial, a través del uso de herramientas tecnológicas'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi62'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '63'},
#   'Titulo': {'type': 'literal',
#    'value': 'Desarrollo de una metodología de visualización interactiva y eficaz de información en Big Data.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi63'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '64'},
#   'Titulo': {'type': 'literal',
#    'value': 'Desarrollo y Aplicación de la Tecnología de Oxidación Avanzada PCFH para Mejorar la Calidad del Agua Potable en el Departamento de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi64'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '350'},
#   'Titulo': {'type': 'literal',
#    'value': 'Diagnóstico Molecular de Virus del Cultivo de Papa (Solanum tuberosum) en los Municipios de la Ex-provincia de Obando.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi350'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '73'},
#   'Titulo': {'type': 'literal',
#    'value': 'Didáctica universitaria, retos desde una realidad local.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi73'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '75'},
#   'Titulo': {'type': 'literal',
#    'value': 'Dinámica de las exportaciones del sector agrícola y su incidencia en el desarrollo rural sostenible en el departamento de Nariño en el periodo 2010-2015'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi75'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '77'},
#   'Titulo': {'type': 'literal',
#    'value': 'Diseño de sistemas de comunicaciones de onda milimétrica'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi77'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '83'},
#   'Titulo': {'type': 'literal',
#    'value': 'EFECTIVIDAD DE ESTRATEGIAS EDUCATIVAS, PARA MEJORAR CONOCIMIENTOS, ACTITUDES Y PRÁCTICAS SOBRE HIPERTENSIÓN ARTERIAL, EN PERSONAS AFILIADAS A LA EPS EMSSANAR, DENTRO DEL MARCO DEL MODELO DE ATENCIÓN INTEGRAL EN SALUD, EN EL MUNICIPIO DE IMUES - NARIÑO DURANTE EL PERIODO 2018 - 2019.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi83'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '91'},
#   'Titulo': {'type': 'literal',
#    'value': 'EFECTO DEL CAMBIO DE USO DEL SUELO SOBRE LA CANTIDAD SUPERFICIAL DEL RECURSO HIDRICO EN LA MICROCUENCA MIJITAYO, MUNICIPIO DE PASTO, DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi91'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '106'},
#   'Titulo': {'type': 'literal',
#    'value': 'ERRORES CONCEPTUALES EN LOS DOCENTES DE CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL DE EDUCACIÓN BÁSICA PRIMARIA DE LAS NORMALES SUPERIORES DE NARIÑO Y PUTUMAYO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi106'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '107'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESPECIES FORESTALES CON POTENCIAL AGROFORESTAL EN LA COSTA PACIFICA, MUNICIPIO DE TUMACO, DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi107'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '117'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTRATEGIAS PEDAGÓGICAS POR COMPETENCIAS EN LAS LICENCIATURAS EN BÁSICA CON ÉNFASIS EN: CIENCIAS SOCIALES- LEBCIS, CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL- LEBCINEA Y DISEÑO GRÁFICO DE LA UNIVERSIDAD DE NARIÑO: 2007-2014.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi117'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '368'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO COMPARATIVO DE METODOLOGÍAS DE DESARROLLO DE SOFTWARE'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi368'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '371'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO COMPUTACIONAL DEL EQUILIBRIO TAUTOMÉRICO EN 1,2,4-TRIAZOLES-3-AMINO-5-SUSTITUIDOS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi371'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '376'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO DE LA PRODUCTIVIDAD EN EL CULTIVO DE CAMARONES EN TANQUES DE GEOMEBRANAS EN EL MUNICIPIO DE TUMACO, MEDIANTE LA IMPLEMENTACIÓN DE UN SISTEMA IOT DE MONITOREO Y CONTROL DE LAS VARIABLES OXÍGENO DISUELTO, TEMPERATURA Y AMONIO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi376'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '377'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO DE LA VULNERABILIDAD EN CUBIERTAS DEL INSTITUTO EDUCATIVO MUNICIPAL TÉCNICO INDUSTRIAL E IGLESIAS NIÑO JESÚS DE LAS PASCUAS Y LA DIVINA PASTORA DEL CORREGIMIENTO DE MAPACHICO ANTE CAÍDA DE CENIZAS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi377'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '126'},
#   'Titulo': {'type': 'literal',
#    'value': 'ESTUDIO DEL POTENCIAL ACUÍCOLA DE LA SABALETA (Brycon henni) ORIGINARIA DE LAS CUENCAS HIDROGRÁFICAS DE LOS RÍOS MAYO Y JUANAMBÚ, DEPARTAMENTO DE NARIÑO, COLOMBIA.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi126'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '382'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN COMUNITARIA DE SERVICIOS ECOSISTÉMICOS DEL HUMEDAL NATURAL DEL CENTRO AMBIENTAL CHIMAYOY, PASTO - NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi382'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '143'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DE LA BIODIVERSIDAD EN SISTEMAS AGROFORESTALES DE LA MICROCUENCA MIJITAYO, MUNICIPIO DE PASTO, DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi143'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '157'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DE TRES TIPOS FOTOBIORREACTORES PARA EL CULTIVO DE MICROALGAS EN EL LABORATORIO DE PRODUCTIVIDAD PRIMARIA DEL PROGRAMA INGENIERÍA EN PRODUCCIÓN ACUÍCOLA DE LA UNIVERSIDAD DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi157'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '159'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DE VARIABLES AGRONÓMICAS MEDIANTE VEHÍCULOS AÉREOS NO TRIPULADOS EN DOS ESPECIES DE IMPORTANCIA AGRONÓMICA EN EL MUNICIPIO DE PASTO, DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi159'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '394'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DEL EFECTO DE SIETE ABONOS VERDES SOBRE EL RENDIMIENTO DE TRES CULTIVOS TRANSITORIOS EN DOS ANDISOLES DEL MUNICIPIO DE PASTO DEPARTAMENTO DE NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi394'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '163'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DEL EFECTO DE UN PROGRAMA DE PREVENCIÓN DE CONDUCTAS SUICIDAS NO LETALES EN ADOLESCENTES ESCOLARIZADOS DE IEM CIUDAD DE PASTO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi163'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '168'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DEL POTENCIAL TURISTÍCO RURAL EN LA RUTA HISTÓRICA DE TACINES, MUNICIPIOS PASTO Y BUESACO, DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi168'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '94'},
#   'Titulo': {'type': 'literal',
#    'value': 'Efecto del Sistema Electrónico para el Suministro de Contingencias en el Comportamiento en el Aula de Clases (SESCCA)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi94'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '360'},
#   'Titulo': {'type': 'literal',
#    'value': 'Efecto del macerado total y del aceite esencial de los frutos maduros de Carica candamarcensis Hook (sin. Vasconcellea pubescens) en la liberación de MMP 9 en neutrófilos aislados de sangre periférica humana, estimulados con LPS (Escherichia coli O55:B5)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi360'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '98'},
#   'Titulo': {'type': 'literal',
#    'value': 'El papel de la mujer en la Ciencia, la tecnología y la innovación en el departamento de Nariño, 2018'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi98'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '103'},
#   'Titulo': {'type': 'literal',
#    'value': 'Elementos teóricos y metodológicos para la construcción de una estrategia comunitaria de prevención de consumo de SPA en la Universidad de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi103'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '111'},
#   'Titulo': {'type': 'literal',
#    'value': 'Estimación del riesgo por flujos de lodos de la quebrada Mijitayo de la ciudad de Pasto en el sector Tamasagra. Parte I'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi111'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '122'},
#   'Titulo': {'type': 'literal',
#    'value': 'Estudio de la variabilidad genética del camarón blanco Litopenaeus vannamei de la región del Pacífico Nariñense mediante análisis de secuencias de ADN por métodos bioinformáticos.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi122'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '127'},
#   'Titulo': {'type': 'literal',
#    'value': 'Estudio fenológico de la flora silvestre nativa con potencial para procesos de restauración ecológica en bosque altoandino del municipio de Pasto, departamento de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi127'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '380'},
#   'Titulo': {'type': 'literal',
# ...
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi271'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '272'},
#   'Titulo': {'type': 'literal',
#    'value': 'Propiedades psicométricas de una prueba para medir el pensamiento crítico a estudiantes de pregrado de Colombia, México y Chile.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi272'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '282'},
#   'Titulo': {'type': 'literal',
#    'value': 'REPRESENTACIONES DE LO INDIGENA EN LOS MANUALES ESCOLARES DE HISTORIA DE COLOMBIA (1948-1990)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi282'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '280'},
#   'Titulo': {'type': 'literal',
#    'value': 'Regeneración "in vitro" de plantas de tomate de arbol (Solanum betaceum Cav.)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi280'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '281'},
#   'Titulo': {'type': 'literal',
#    'value': 'Relevancia del plan o catálogo de cuentas de cara al nuevo marco técnico normativo en el proceso de enseñanza-aprendizaje de la contabilidad en los programas de contaduría pública en las universidades de la ciudad de Pasto'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi281'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '284'},
#   'Titulo': {'type': 'literal',
#    'value': 'Resolución de problemas: un medio para la formación matemática'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi284'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '286'},
#   'Titulo': {'type': 'literal',
#    'value': 'Revisión del estado actual del curso Termodinámica y su disponibilidad de equipos de laboratorio.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi286'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '276'},
#   'Titulo': {'type': 'literal', 'value': 'Rápido Prototipado'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi276'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '288'},
#   'Titulo': {'type': 'literal',
#    'value': 'SEMISÍNTESIS DE BETAXANTINAS, ESTUDIO DE SU ESTABILIDAD Y DE SU ACTIVIDAD ANTIOXIDANTE IN VITRO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi288'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '291'},
#   'Titulo': {'type': 'literal',
#    'value': 'SISTEMA COMPUTACIONAL DE APOYO A LA GENERACIÓN DE HORARIOS DE CLASES PARA LA FACULTAD DE INGENIERÍA DE LA UNIVERSIDAD DE NARIÑO BASADO EN ALGORITMOS GENÉTICOS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi291'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '293'},
#   'Titulo': {'type': 'literal',
#    'value': 'Sistema de Información Integral Hacia la Estandarización de los Procesos de Producción de Cafés Especiales en el Municipio de Buesaco'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi293'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '292'},
#   'Titulo': {'type': 'literal',
#    'value': 'Sistema de aprendizaje interactivo para la apropiación del conocimiento agroforestal'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi292'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '441'},
#   'Titulo': {'type': 'literal',
#    'value': 'Tramas y urdimbres de pensamiento, narrativas en la Guanga. Resguardo de Pastas, proyecto de investigación creación'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi441'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '443'},
#   'Titulo': {'type': 'literal',
#    'value': 'UMAYUX: UN MODELO DE SOFTWARE DE GESTION DE CONOCIMIENTO SOPORTADO EN UNA ONTOLOGIA DINAMICA DEBILMENTE ACOPLADO CON UN GESTOR DE BASE DE DATOS PARA LA UNIVERSIDAD DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi443'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '444'},
#   'Titulo': {'type': 'literal',
#    'value': 'UN APLICACIÓN DE BASES DE DATOS NoSQL PARA LA GESTIÓN DE INFORMACIÓN DE EGRESADOS DEL PROGRAMA DE INGENIERÍA DE SISTEMAS DE LA UNIVERSIDAD DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi444'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '304'},
#   'Titulo': {'type': 'literal',
#    'value': 'VALIDACIÓN DE HERRAMIENTAS DIDÁCTICAS PARA LA ENSEÑANZA AGROFORESTAL, EN LAS VEREDAS SAN FELIPE, NUEVA CAMPILLA Y MARQUEZA, DEPARTAMENTO DE NARIÑO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi304'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '448'},
#   'Titulo': {'type': 'literal',
#    'value': 'VALORACIÓN DEL EXTRACTO DE LOS FRUTOS DE Leandra subseriata (Naudin) Cong COMO AGENTE ANTIOXIDANTE Y DE REGULACIÓN DE LIBERACIÓN GRÁNULOS DE GELATINASA EN NEUTRÓFILOS HUMANOS'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi448'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '305'},
#   'Titulo': {'type': 'literal',
#    'value': 'Variabilidad genética y su relación con la especificidad de hospedero en aislamientos de Phytophthora obtenidos de diferentes especies de Solanáceas cultivadas en el sur de Colombia.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi305'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '451'},
#   'Titulo': {'type': 'literal',
#    'value': 'Visibilidad y reconocimiento del Departamento de Diseño de la Universidad de Nariño a partir del diseño colaborativo.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi451'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '409'},
#   'Titulo': {'type': 'literal',
#    'value': 'investigación participativa para el fortalecimiento del proyecto ambiental escolar (PRAE) en el corregimiento de Morasurco del municipío de Pasto, Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi409'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '308'},
#   'Titulo': {'type': 'literal',
#    'value': '¿Qué conocimiento tienen los educadores matemáticos en formación de la Universidad de Nariño para promover el estudio de la conversión a través de la enseñanza del infinito mediado por el uso del CABRI? Un estudio de diseños de enseñanza.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi308'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '2'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '309'},
#   'Titulo': {'type': 'literal',
#    'value': 'AISLAMIENTO, CARACTERIZACION, ESTABILIDAD Y ACTIVIDAD ANTIOXIDANTE IN - VITRO DE LOS PIGMENTOS TIPO BETALAINAS DEL FRUTO DE Opuntia dillenii.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi309'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '353'},
#   'Titulo': {'type': 'literal',
#    'value': 'DISEÑO DE UN ESPACIO FÍSICO PARA LA PROMOCIÓN DE LA LECTURA CON NIÑOS Y NIÑAS DE 4 A 6 AÑOS DE LA INSTITUCIÓN EDUCATIVA MUNICIPAL ANTONIO NARIÑO EN LA CIUDAD DE PASTO'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi353'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '67'},
#   'Titulo': {'type': 'literal',
#    'value': 'Detección molecular de geminivirus asociados al cultivo de tomate (Solanum lycopersicum L.) en el departamento de Nariño'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi67'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '386'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DE LA COMPATIBILIDAD SEXUAL EN CLONES DE CACAO (Theobroma cacao L), REGIONAL EN EL MUNICIPIO DE TUMACO NARIÑO.'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi386'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '164'},
#   'Titulo': {'type': 'literal',
#    'value': 'EVALUACIÓN DEL EFECTO DEL ALMACENAMIENTO CON ETANOL, SOBRE ALGUNAS CARACTERISTICAS FISICOQÍMICAS Y SENSORIALES DE PAPAS NATIVAS (Solanum spp)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi164'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '135'},
#   'Titulo': {'type': 'literal',
#    'value': 'Evaluación de dos tecnologías emergentes (microondas y ultrasonido) para la extracción de compuestos antioxidantes de cáscara de papa (Solanum tuberosum) de la variedad diacol capiro .'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi135'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '402'},
#   'Titulo': {'type': 'literal',
#    'value': 'FORMULACIÓN DE UN BIOFUNGICIDA A PARTIR DE UNA EMULSION CON ACEITE ESENCIAL DE OREGANO SILVESTRE (Lippia origanoides H.B.K) FRENTE AL FITOPATOGENO Fusarium oxysporum f. sp. pisi CAUSANTE DE MARCHITEZ VASCULAR DE ARVEJA (Pisum Sativum L.)'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi402'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '403'},
#   'Titulo': {'type': 'literal',
#    'value': 'FP-FLOCK: UN ALGORITMO PARA EL DESCUBRIMIENTO DE PATRONES DE AGRUPACIÓN DE OBJETOS MÓVILES EN BASES DE DATOS ESPACIO TEMPORALES'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi403'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '206'},
#   'Titulo': {'type': 'literal',
#    'value': 'Identificación y Análisis de la Dinámica de Mortalidad y supervivencia empresarial en el Municipio de Ipiales en el periodo 2000-2016'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi206'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}},
#  {'id_pi': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '449'},
#   'Titulo': {'type': 'literal',
#    'value': 'Valoración económica de los servicios ecosistémicos laguna de La Cocha, vereda Romerillo, corregimiento El Encano'},
#   'proyecto_investigacion': {'type': 'uri',
#    'value': 'http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi449'},
#   'c': {'type': 'literal',
#    'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'value': '1'}}]

# %%
id_docs = [result['id_pi']['value'] for result in results ]
len(id_docs)
# Out:
# 163

# %%
results = sparql.query().convert()

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../Scripts')
from ontologia import *

# %%
sync_reasoner() g
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/sangeeky/anaconda3/envs/tesis/lib/python3.7/site-packages/owlready2/hermit:/home/sangeeky/anaconda3/envs/tesis/lib/python3.7/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpuvntmp6v
# * Owlready2 * HermiT took 14.36101770401001 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
palabra = (ontologia.Palabra.instances())[0]
trabajo = (palabra.palabra_describe_pi)[0]
trabajo
# Out:
# OntologiaInvestigacionPrueba.pi1

# %%
print(trabajo.is_a)
#print(ontologia.get_instances_of(parent))
print(ontologia.get_parents_of(Facultad))
print(ontologia.get_children_of(Universidad))
# Out:
# [OntologiaInvestigacionPrueba.Proyecto_investigacion]
# [OntologiaInvestigacionPrueba.Universidad]
# [OntologiaInvestigacionPrueba.VIIS, OntologiaInvestigacionPrueba.Facultad]

# %%
graph = default_world.as_rdflib_graph()

# %%
qres = g.query(
    """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX po: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
select ?id_pi?Titulo?proyecto_investigacion (count(?id_pi)as ?c)
where{
        # ?proyecto_investigacion po:pi_tiene_palabra ?palabra.
        # ?proyecto_investigacion po:titulo_proyecto_investigacion ?Titulo.
        # ?proyecto_investigacion po:id_proyecto_investigacion ?id_pi.
        # ?palabra po:descripcion_palabra ?descripcion.
        FILTER (
            REGEX(str(?descripcion), 'descubrimiento','i')||
            REGEX(str(?descripcion), 'conocimiento','i')
        )
    }
group by ?id_pi?Titulo?proyecto_investigacion
""")

# %%
qres = g.query(
    """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX po: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
select ?id_pi?Titulo?proyecto_investigacion (count(?id_pi)as ?c)
where{
        # ?palabras po:palabra_describe_pi ?proyecto_investigacion.
        # ?proyecto_investigacion po:titulo_proyecto_investigacion ?Titulo.
        # ?proyecto_investigacion po:id_proyecto_investigacion ?id_pi.
        # ?palabras po:descripcion_palabra ?descripcion.
        FILTER (
            REGEX(str(?descripcion), 'descubrimiento','i')||
            REGEX(str(?descripcion), 'conocimiento','i')
        )
    }
group by ?id_pi?Titulo?proyecto_investigacion
order by DESC(?c)
""")

# %%
#Directa
trabajos = list(graph.query("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX po: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
select ?id_pi?Titulo?proyecto_investigacion (count(?id_pi)as ?c)
where{
        # ?proyecto_investigacion po:pi_tiene_palabra ?palabra.
        # ?proyecto_investigacion po:titulo_proyecto_investigacion ?Titulo.
        # ?proyecto_investigacion po:id_proyecto_investigacion ?id_pi.
        # ?palabra po:descripcion_palabra ?descripcion.
        FILTER (
            REGEX(str(?descripcion), 'descubrimiento','i')||
            REGEX(str(?descripcion), 'conocimiento','i')
        )
    }
group by ?id_pi?Titulo?proyecto_investigacion
order by DESC(?c)
"""))

#trabajos

# %%
trabajos[1]
# Out:
# (rdflib.term.Literal('204', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  rdflib.term.Literal('HONGOS FITOPATÓGENOS ASOCIADOS AL LAUREL DE CERA Morella pubescens', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  rdflib.term.URIRef('http://www.semanticweb.org/OntologiaInvestigacionPrueba#pi204'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
#Inversa
trabajos = graph.query("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX po: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
select ?id_pi?Titulo?proyecto_investigacion (count(?id_pi)as ?c)
where{
        # ?palabras po:descripcion_palabra ?descripcion.
        # ?palabras po:palabra_describe_pi ?proyecto_investigacion.
        # ?proyecto_investigacion po:titulo_proyecto_investigacion ?Titulo.
        # ?proyecto_investigacion po:id_proyecto_investigacion ?id_pi.
        FILTER (
            REGEX(str(?descripcion), 'descubrimiento','i')||
            REGEX(str(?descripcion), 'conocimiento','i')
        )
    }
group by ?id_pi?Titulo?proyecto_investigacion
order by DESC(?c)
""")

trabajos
# Out:
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.i.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.i.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.e . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.e . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.c . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.c . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.s.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.s.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.d . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.d . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#l.f . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#l.f . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b.k . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b.k . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#p.t.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#p.t.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#i.d.s . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#i.d.s . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.v . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.v . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.v . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.v . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#j.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#j.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#m.s.n.m . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.f . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.f . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#h.b . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.g . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.g . does not look like a valid URI, trying to serialize this will break.
